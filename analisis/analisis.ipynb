# %%
import numpy as np
np.__version__
# Out:
# '1.25.0'

# %%
import pandas as pd
pd.__version__
# Out:
# '2.0.3'

# %%
import matplotlib.pyplot as plt

# %%
archivo = 'archivo2.csv'
df = pd.read_csv(
    archivo,
    encoding="latin1",
)

# %%
df_copy = df.copy()

# %%
df_copy
# Out:
#        Year Date Of Incident    Route        Operator     Group Name  \
# 0      2015       01/01/2015        1  London General       Go-Ahead
# 1      2015       01/01/2015        4       Metroline      Metroline
# 2      2015       01/01/2015        5     East London     Stagecoach
# 3      2015       01/01/2015        5     East London     Stagecoach
# 4      2015       01/01/2015        6       Metroline      Metroline
# ...     ...              ...      ...             ...            ...
# 23153  2018       01/09/2018  (blank)     East London     Stagecoach
# 23154  2018       01/09/2018  (blank)   London United  London United
# 23155  2018       01/09/2018  (blank)   London United  London United
# 23156  2018       01/09/2018  (blank)   London United  London United
# 23157  2018       01/09/2018  (blank)       Metroline      Metroline
#
#                  Bus Garage               Borough  \
# 0      Garage Not Available             Southwark
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23158 entries, 0 to 23157
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       23158 non-null  int64
#  1   Date Of Incident           23158 non-null  object
#  2   Route                      23158 non-null  object
#  3   Operator                   23158 non-null  object
#  4   Group Name                 23158 non-null  object
#  5   Bus Garage                 23158 non-null  object
#  6   Borough                    23158 non-null  object
#  7   Injury Result Description  23158 non-null  object
#  8   Incident Event Type        23158 non-null  object
#  9   Victim Category            23158 non-null  object
#  10  Victims Sex                23158 non-null  object
#  11  Victims Age                23158 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 2.1+ MB

# %%
df_copy = df_copy.rename(columns={'Date Of Incident':'Date_Incident', 'Group Name':'Group_Name', 'Bus Garage':'Bus_Garage','Injury Result Description':'Injury_Result_Description','Incident Event Type':'Incident_Type','Victim Category':'Victim_Category','Victims Sex':'Victims_Sex','Victims Age':'Victims_Age'})

# %%
df_copy.head()
# Out:
#    Year Date_Incident Route        Operator  Group_Name            Bus_Garage  \
# 0  2015    01/01/2015     1  London General    Go-Ahead  Garage Not Available
# 1  2015    01/01/2015     4       Metroline   Metroline  Garage Not Available
# 2  2015    01/01/2015     5     East London  Stagecoach  Garage Not Available
# 3  2015    01/01/2015     5     East London  Stagecoach  Garage Not Available
# 4  2015    01/01/2015     6       Metroline   Metroline  Garage Not Available
#
#                Borough                          Injury_Result_Description  \
# 0            Southwark                          Injuries treated on scene
# 1            Islington                          Injuries treated on scene
# 2             Havering  Taken to Hospital  Reported Serious Injury or...
# 3  None London Borough  Taken to Hospital  Reported Serious Injury or...
# 4          Westminster        Reported Minor Injury - Treated at Hospital
#
# ...

# %%
df_copy.head(3)
# Out:
#    Year Date_Incident Route        Operator  Group_Name            Bus_Garage  \
# 0  2015    01/01/2015     1  London General    Go-Ahead  Garage Not Available
# 1  2015    01/01/2015     4       Metroline   Metroline  Garage Not Available
# 2  2015    01/01/2015     5     East London  Stagecoach  Garage Not Available
#
#      Borough                          Injury_Result_Description  \
# 0  Southwark                          Injuries treated on scene
# 1  Islington                          Injuries treated on scene
# 2   Havering  Taken to Hospital  Reported Serious Injury or...
#
#       Incident_Type Victim_Category Victims_Sex Victims_Age
# 0  Onboard Injuries       Passenger        Male       Child
# 1  Onboard Injuries       Passenger        Male     Unknown
# 2  Onboard Injuries       Passenger        Male     Elderly

# %%
df_copy = pd.DataFrame(df_copy)
df_copy
# Out:
#        Year Date_Incident    Route        Operator     Group_Name  \
# 0      2015    01/01/2015        1  London General       Go-Ahead
# 1      2015    01/01/2015        4       Metroline      Metroline
# 2      2015    01/01/2015        5     East London     Stagecoach
# 3      2015    01/01/2015        5     East London     Stagecoach
# 4      2015    01/01/2015        6       Metroline      Metroline
# ...     ...           ...      ...             ...            ...
# 23153  2018    01/09/2018  (blank)     East London     Stagecoach
# 23154  2018    01/09/2018  (blank)   London United  London United
# 23155  2018    01/09/2018  (blank)   London United  London United
# 23156  2018    01/09/2018  (blank)   London United  London United
# 23157  2018    01/09/2018  (blank)       Metroline      Metroline
#
#                  Bus_Garage               Borough  \
# 0      Garage Not Available             Southwark
# 1      Garage Not Available             Islington
# ...

# %%
df_copy = df_copy.replace({'Cyclist ':'Cyclist'})

# %%
df_copy[(df_copy.Victim_Category=='Cyclist ')]
# Out:
# Empty DataFrame
# Columns: [Year, Date_Incident, Route, Operator, Group_Name, Bus_Garage, Borough, Injury_Result_Description, Incident_Type, Victim_Category, Victims_Sex, Victims_Age]
# Index: []

# %%
df_copy[(df_copy.Victim_Category=='Cyclist')]
# Out:
#        Year Date_Incident Route             Operator     Group_Name  \
# 57     2015    01/01/2015    37             Metrobus       Go-Ahead
# 74     2015    01/01/2015    52            Metroline      Metroline
# 131    2015    01/01/2015   109  Arriva London South  Arriva London
# 195    2015    01/01/2015   181             Metrobus       Go-Ahead
# 234    2015    01/01/2015   242  Arriva London North  Arriva London
# ...     ...           ...   ...                  ...            ...
# 22861  2018    01/09/2018   155       London General       Go-Ahead
# 22873  2018    01/09/2018   166  Arriva London South  Arriva London
# 22940  2018    01/09/2018   242  Arriva London North  Arriva London
# 23023  2018    01/09/2018   337       London General       Go-Ahead
# 23098  2018    01/09/2018   521       London General       Go-Ahead
#
#                  Bus_Garage               Borough  \
# 57     Garage Not Available            Wandsworth
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23158 entries, 0 to 23157
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       23158 non-null  int64
#  1   Date_Incident              23158 non-null  object
#  2   Route                      23158 non-null  object
#  3   Operator                   23158 non-null  object
#  4   Group_Name                 23158 non-null  object
#  5   Bus_Garage                 23158 non-null  object
#  6   Borough                    23158 non-null  object
#  7   Injury_Result_Description  23158 non-null  object
#  8   Incident_Type              23158 non-null  object
#  9   Victim_Category            23158 non-null  object
#  10  Victims_Sex                23158 non-null  object
#  11  Victims_Age                23158 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 2.1+ MB

# %%
df_copy = df_copy.replace({'Motorcyclist ':'Motorcyclist'})
df_copy
# Out:
#        Year Date_Incident    Route        Operator     Group_Name  \
# 0      2015    01/01/2015        1  London General       Go-Ahead
# 1      2015    01/01/2015        4       Metroline      Metroline
# 2      2015    01/01/2015        5     East London     Stagecoach
# 3      2015    01/01/2015        5     East London     Stagecoach
# 4      2015    01/01/2015        6       Metroline      Metroline
# ...     ...           ...      ...             ...            ...
# 23153  2018    01/09/2018  (blank)     East London     Stagecoach
# 23154  2018    01/09/2018  (blank)   London United  London United
# 23155  2018    01/09/2018  (blank)   London United  London United
# 23156  2018    01/09/2018  (blank)   London United  London United
# 23157  2018    01/09/2018  (blank)       Metroline      Metroline
#
#                  Bus_Garage               Borough  \
# 0      Garage Not Available             Southwark
# 1      Garage Not Available             Islington
# ...

# %%
df_copy[(df_copy.Victim_Category=='Motorcyclist')]
# Out:
#        Year Date_Incident Route           Operator         Group_Name  \
# 133    2015    01/01/2015   111      London United      London United
# 253    2015    01/01/2015   268  Arriva The Shires  Arriva The Shires
# 399    2015    01/04/2015     1     London General           Go-Ahead
# 798    2015    01/04/2015   493     London General           Go-Ahead
# 858    2015    01/04/2015    S3       H R Richmond       Quality Line
# ...     ...           ...   ...                ...                ...
# 21018  2018    01/05/2018   H91      London United      London United
# 21038  2018    01/05/2018   P13     Abellio London            Abellio
# 21155  2018    01/06/2018    46          Metroline          Metroline
# 21742  2018    01/07/2018    76     London General           Go-Ahead
# 22382  2018    01/08/2018   177            Selkent         Stagecoach
#
#                  Bus_Garage               Borough  \
# 133    Garage Not Available              Hounslow
# ...

# %%
df_copy[(df_copy.Victim_Category=='Motorcyclist ')]
# Out:
# Empty DataFrame
# Columns: [Year, Date_Incident, Route, Operator, Group_Name, Bus_Garage, Borough, Injury_Result_Description, Incident_Type, Victim_Category, Victims_Sex, Victims_Age]
# Index: []

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23158 entries, 0 to 23157
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       23158 non-null  int64
#  1   Date_Incident              23158 non-null  object
#  2   Route                      23158 non-null  object
#  3   Operator                   23158 non-null  object
#  4   Group_Name                 23158 non-null  object
#  5   Bus_Garage                 23158 non-null  object
#  6   Borough                    23158 non-null  object
#  7   Injury_Result_Description  23158 non-null  object
#  8   Incident_Type              23158 non-null  object
#  9   Victim_Category            23158 non-null  object
#  10  Victims_Sex                23158 non-null  object
#  11  Victims_Age                23158 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 2.1+ MB

# %%
df_copy
# Out:
#        Year Date_Incident    Route        Operator     Group_Name  \
# 0      2015    01/01/2015        1  London General       Go-Ahead
# 1      2015    01/01/2015        4       Metroline      Metroline
# 2      2015    01/01/2015        5     East London     Stagecoach
# 3      2015    01/01/2015        5     East London     Stagecoach
# 4      2015    01/01/2015        6       Metroline      Metroline
# ...     ...           ...      ...             ...            ...
# 23153  2018    01/09/2018  (blank)     East London     Stagecoach
# 23154  2018    01/09/2018  (blank)   London United  London United
# 23155  2018    01/09/2018  (blank)   London United  London United
# 23156  2018    01/09/2018  (blank)   London United  London United
# 23157  2018    01/09/2018  (blank)       Metroline      Metroline
#
#                  Bus_Garage               Borough  \
# 0      Garage Not Available             Southwark
# 1      Garage Not Available             Islington
# ...

# %%
df_category = df_copy["Victim_Category"].value_counts()
df_category = pd.DataFrame(df_category)
df_category
# Out:
#                              count
# Victim_Category
# Passenger                    18828
# Pedestrian                    1612
# Bus Driver                    1484
# 3rd Party driver / Occupant    573
# Cyclist                        308
# Member Of Public               127
# Motorcyclist                   106
# Operational Staff               59
# Conductor                       28
# Other                           16
# Contractor Staff                 6
# Non-Operational Staff            4
# TfL Staff                        4
# Insufficient Data                2
# Operations staff (other)         1

# %%
group_incident = df_copy.groupby(by=['Victim_Category'])
group_incident.head()
# Out:
#        Year Date_Incident Route        Operator     Group_Name  \
# 0      2015    01/01/2015     1  London General       Go-Ahead
# 1      2015    01/01/2015     4       Metroline      Metroline
# 2      2015    01/01/2015     5     East London     Stagecoach
# 3      2015    01/01/2015     5     East London     Stagecoach
# 4      2015    01/01/2015     6       Metroline      Metroline
# ...     ...           ...   ...             ...            ...
# 16866  2017    01/10/2017   134       Metroline      Metroline
# 17819  2017    01/11/2017   OOS  London Central       Go-Ahead
# 18896  2018    01/01/2018   OOS  London Central       Go-Ahead
# 21988  2018    01/07/2018   294     East London     Stagecoach
# 22030  2018    01/07/2018   328   Tower Transit  Tower Transit
#
#                         Bus_Garage               Borough  \
# 0             Garage Not Available             Southwark
# 1             Garage Not Available             Islington
# ...

# %%
df_category = group_incident["Victim_Category"].value_counts()
df_category
# Out:
# Victim_Category
# 3rd Party driver / Occupant      573
# Bus Driver                      1484
# Conductor                         28
# Contractor Staff                   6
# Cyclist                          308
# Insufficient Data                  2
# Member Of Public                 127
# Motorcyclist                     106
# Non-Operational Staff              4
# Operational Staff                 59
# Operations staff (other)           1
# Other                             16
# Passenger                      18828
# Pedestrian                      1612
# TfL Staff                          4
# Name: count, dtype: int64

# %%
df_category.index
# Out:
# Index(['3rd Party driver / Occupant', 'Bus Driver', 'Conductor',
#        'Contractor Staff', 'Cyclist', 'Insufficient Data', 'Member Of Public',
#        'Motorcyclist', 'Non-Operational Staff', 'Operational Staff',
#        'Operations staff (other)', 'Other', 'Passenger', 'Pedestrian',
#        'TfL Staff'],
#       dtype='object', name='Victim_Category')

# %%
plt.barh(df_category.index,df_category.values)
plt.xlabel("Categoria de usuarios")
plt.ylabel("Total de victimas")
plt.title("Grafica de victimas por cada categoria de usuarios")
plt.show()

# %%
group_Age = df_copy.groupby(by=['Victims_Age'])
group_Age.head()
# Out:
#      Year Date_Incident Route               Operator             Group_Name  \
# 0    2015    01/01/2015     1         London General               Go-Ahead
# 1    2015    01/01/2015     4              Metroline              Metroline
# 2    2015    01/01/2015     5            East London             Stagecoach
# 3    2015    01/01/2015     5            East London             Stagecoach
# 4    2015    01/01/2015     6              Metroline              Metroline
# 5    2015    01/01/2015     6              Metroline              Metroline
# 6    2015    01/01/2015     8                Selkent             Stagecoach
# 7    2015    01/01/2015     9          London United          London United
# 8    2015    01/01/2015    10          London United          London United
# 9    2015    01/01/2015    11         London General               Go-Ahead
# 10   2015    01/01/2015    11         London General               Go-Ahead
# ...

# %%
df_edad = df_copy["Victims_Age"].value_counts()
df_edad
# Out:
# Victims_Age
# Adult      10754
# Unknown     7135
# Elderly     2769
# Child       2181
# Youth        319
# Name: count, dtype: int64

# %%
plt.barh(df_edad.index,df_edad.values)
plt.xlabel("Edad de usuarios")
plt.ylabel("Total de victimas")
plt.title("Grafica de victimas por cada edad de usuarios")
plt.show()

# %%
df = pd.DataFrame(df_copy,columns=['Victim_Category','Victims_Age'])
df['Cantidad'] = ''
df
# Out:
#          Victim_Category Victims_Age Cantidad
# 0              Passenger       Child
# 1              Passenger     Unknown
# 2              Passenger     Elderly
# 3              Passenger     Elderly
# 4             Pedestrian     Elderly
# ...                  ...         ...      ...
# 23153         Bus Driver       Adult
# 23154         Bus Driver       Adult
# 23155  Operational Staff       Adult
# 23156         Bus Driver       Adult
# 23157              Other     Unknown
#
# [23158 rows x 3 columns]

# %%
df2 = pd.DataFrame.groupby(df, by=['Victim_Category','Victims_Age'])
cantidad_category_age = df2.count()

# %%
cantidad_category_age
# Out:
#                                          Cantidad
# Victim_Category             Victims_Age
# 3rd Party driver / Occupant Adult             345
#                             Child              33
#                             Elderly            30
#                             Unknown           163
#                             Youth               2
# Bus Driver                  Adult            1476
#                             Elderly             3
#                             Unknown             5
# Conductor                   Adult              10
#                             Unknown            18
# Contractor Staff            Adult               6
# Cyclist                     Adult             180
#                             Child              10
#                             Elderly             4
#                             Unknown           106
#                             Youth               8
# Insufficient Data           Unknown             2
# ...

# %%
df1= cantidad_category_age['Cantidad']
df1_occupant = df1['3rd Party driver / Occupant']
plt.barh(df1_occupant.index,df1_occupant.values)
plt.ylabel("Edad de usuarios")
plt.xlabel("Total de victimas")
plt.title("Grafica de victimas Occupant")
plt.show()

# %%
df3= cantidad_category_age['Cantidad']
df3_occupant = df3['Passenger']
plt.barh(df3_occupant.index,df3_occupant.values)
plt.ylabel("Edad de usuarios")
plt.xlabel("Total de victimas")
plt.title("Grafica de victimas Passenger")
plt.show()

# %%
df4 = cantidad_category_age['Cantidad']
df4_occupant = df4['Cyclist']
plt.barh(df4_occupant.index,df4_occupant.values)
plt.ylabel("Edad de usuarios")
plt.xlabel("Total de victimas")
plt.title("Grafica de victimas Cyclist")
plt.show()
